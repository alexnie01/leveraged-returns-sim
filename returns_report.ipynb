# %% [markdown]
# # Returns Report
#
# Set parameters below and run the cell. Figures are displayed here; HTML reports are written beside the notebook.

# %%
from pathlib import Path

from returns_report import ReportConfig, generate_report

config = ReportConfig(
    use_historical=True,
    ticker="QQQ",
    annual_drift=0.12,
    annual_volatility=0.20,
    n_trials=1000,
    n_days=10000,
    random_seed=44,
    show_mc_trials=True,
    n_workers=None,
    html_output=Path("returns_report.html"),
)

report = generate_report(config)
